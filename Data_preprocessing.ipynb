# %% [markdown]
# <a href="https://colab.research.google.com/github/harshath2000/Into_to_ML_FinalProject/blob/main/Data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import librosa
import numpy as np
from tqdm import tqdm

# %%
def extract_features(file_path, sampling_rate=48000):
    try:
        y, _ = librosa.load(file_path, sr=sampling_rate)

        spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sampling_rate)[0]
        spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sampling_rate)[0]
        spectral_rolloff = librosa.feature.spectral_rolloff(y=y, sr=sampling_rate)[0]

        mfccs = librosa.feature.mfcc(y=y, sr=sampling_rate)

        chroma = librosa.feature.chroma_stft(y=y, sr=sampling_rate)

        contrast = librosa.feature.spectral_contrast(y=y, sr=sampling_rate)

        tonnetz = librosa.feature.tonnetz(y=librosa.effects.harmonic(y), sr=sampling_rate)

        rmse = librosa.feature.rms(y=y)[0]

        # Concatenate all features into a single 1D array
        all_features = [spectral_centroid.mean(), spectral_bandwidth.mean(), spectral_rolloff.mean()] + \
                        list(mfccs.mean(axis=1)) + list(chroma.mean(axis=1)) + list(contrast.mean(axis=1)) + \
                        list(tonnetz.mean(axis=1)) + [rmse.mean()]

        return all_features

    except Exception as e:
        print(f"Error processing {file_path}: {e}")
        return None

# %%
csv_path = '/content/cv-valid-test.csv'  # Replace with your actual CSV file path
df = pd.read_csv(csv_path)

# %%
df_sampled = df.dropna(subset=['age'])
df_sampled = df_sampled.reset_index(drop=True)
df_sampled.tail()
# Out:
#            filename                                               text  \
# 1537  sample-003976                              we've got her located
# 1538  sample-003979                          she has all your features
# 1539  sample-003980                  i've got to see nicole right away
# 1540  sample-003984  but there were certain of them who took a bit ...
# 1541  sample-003989                              i'm playing for keeps
#
#       up_votes  down_votes       age gender     accent  duration
# 1537         1           0  thirties   male    england       NaN
# 1538         1           0  thirties   male        NaN       NaN
# 1539         1           0   fifties   male  australia       NaN
# 1540         2           0  thirties   male        NaN       NaN
# 1541         2           0   fifties   male  australia       NaN

# %%
features_list = []
for index, row in tqdm(df_sampled.iterrows(), total=len(df_sampled), desc="Processing files"):
    filename = row['filename']
    age = row['age']

    # Search for the corresponding .mp3 file in the folder
    mp3_path = f'/content/cv-valid-test.csv'  # Replace with your actual folder path
    if os.path.exists(mp3_path):
        # Extract features using librosa with try-except
        features = extract_features(mp3_path)
        if features is not None:
            features_list.append([filename, age] + features)
features_df = pd.DataFrame(features_list, columns=['filename', 'age', 'spectral_centroid', 'spectral_bandwidth',
                                                   'spectral_rolloff'] + [f'mfcc_{i}' for i in range(1, 21)] +
                                                  [f'chroma_{i}' for i in range(1, 13)] +
                                                  [f'contrast_{i}' for i in range(1, 8)] +
                                                  [f'tonnetz_{i}' for i in range(1, 7)] + ['rmse'])

# Save the final DataFrame to a new CSV file
output_csv_path = '/content/test1_extracted_features.csv'  # Replace with your desired output path
features_df.to_csv(output_csv_path, index=False)

print(f"Processed {len(features_df)} files and saved features to {output_csv_path}")
# Out:
# Processing files:   0%|          | 0/1542 [00:00<?, ?it/s]<ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   0%|          | 1/1542 [00:00<05:41,  4.51it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   0%|          | 2/1542 [00:00<05:34,  4.61it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:
/s]<ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▍         | 71/1542 [00:16<05:11,  4.73it/s]
# Error processing /content/cv-valid-test.csv:
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▍         | 72/1542 [00:16<05:10,  4.74it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▍         | 73/1542 [00:16<05:22,  4.56it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▍         | 74/1542 [00:16<05:14,  4.67it/s]<ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Error processing /content/cv-valid-test.csv:
# Processing files:   5%|▍         | 75/1542 [00:17<05:13,  4.68it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▍         | 76/1542 [00:17<05:08,  4.75it/s]<ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Error processing /content/cv-valid-test.csv:
# Processing files:   5%|▍         | 77/1542 [00:17<05:08,  4.75it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▌         | 78/1542 [00:17<05:15,  4.65it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▌         | 79/1542 [00:18<05:13,  4.67it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▌         | 80/1542 [00:18<05:14,  4.64it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▌         | 81/1542 [00:18<05:15,  4.62it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▌         | 82/1542 [00:18<05:19,  4.57it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▌         | 83/1542 [00:18<05:23,  4.51it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   5%|▌         | 84/1542 [00:19<05:24,  4.49it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   6%|▌         | 85/1542 [00:19<05:28,  4.44it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   6%|▌         | 86/1542 [00:19<05:33,  4.36it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   6%|▌         | 87/1542 [00:19<05:28,  4.43it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   6%|▌         | 88/1542 [00:20<05:27,  4.44it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   6%|▌         | 89/1542 [00:20<05:20,  4.54it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   6%|▌         | 90/1542 [00:20<05:17,  4.57it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:   6%|▌         | 91/1542 [00:20<05:22,  4.49it/s]
# Error processing /content/cv-valid-test.csv:
# ...
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  98%|█████████▊| 1513/1542 [06:38<00:09,  3.01it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  98%|█████████▊| 1514/1542 [06:38<00:09,  2.92it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  98%|█████████▊| 1515/1542 [06:39<00:08,  3.02it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  98%|█████████▊| 1516/1542 [06:39<00:08,  2.91it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  98%|█████████▊| 1517/1542 [06:39<00:08,  2.97it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  98%|█████████▊| 1518/1542 [06:40<00:07,  3.23it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▊| 1519/1542 [06:40<00:06,  3.37it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▊| 1520/1542 [06:40<00:06,  3.48it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▊| 1521/1542 [06:40<00:05,  3.72it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▊| 1522/1542 [06:41<00:05,  3.81it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1523/1542 [06:41<00:05,  3.77it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1524/1542 [06:41<00:04,  3.82it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1525/1542 [06:41<00:04,  3.91it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1526/1542 [06:42<00:04,  3.99it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1527/1542 [06:42<00:03,  3.83it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1528/1542 [06:42<00:03,  3.96it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1529/1542 [06:42<00:03,  4.01it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1530/1542 [06:43<00:03,  3.90it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1531/1542 [06:43<00:02,  4.00it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1532/1542 [06:43<00:02,  3.90it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1533/1542 [06:43<00:02,  4.00it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files:  99%|█████████▉| 1534/1542 [06:44<00:01,  4.07it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files: 100%|█████████▉| 1535/1542 [06:44<00:01,  4.09it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files: 100%|█████████▉| 1536/1542 [06:44<00:01,  4.06it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files: 100%|█████████▉| 1537/1542 [06:44<00:01,  4.13it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files: 100%|█████████▉| 1538/1542 [06:45<00:00,  4.04it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files: 100%|█████████▉| 1539/1542 [06:45<00:00,  4.09it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files: 100%|█████████▉| 1540/1542 [06:45<00:00,  4.06it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files: 100%|█████████▉| 1541/1542 [06:45<00:00,  4.00it/s]
# Error processing /content/cv-valid-test.csv:
# <ipython-input-3-053cc6ed2dca>:3: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, _ = librosa.load(file_path, sr=sampling_rate)
# /usr/local/lib/python3.10/dist-packages/librosa/core/audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Processing files: 100%|██████████| 1542/1542 [06:46<00:00,  3.80it/s]
# Error processing /content/cv-valid-test.csv:
# Processed 0 files and saved features to /content/test1_extracted_features.csv
